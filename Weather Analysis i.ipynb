# %% [markdown]
# # IMPORT PANDAS

# %%
import pandas as pd

# %% [markdown]
# # IMPORT NUMPY

# %%
import numpy as np

# %% [markdown]
# # IMPORT MATPLOTLIB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # IMPORT CSV FILE

# %%
my_data = pd.read_csv(r"C:\Users\eakal\Desktop\DSL\DSL Projects\weatherAUS.csv")

# %%
my_data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %%
my_data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0           W           44.0          W      ...             22.0
# 1         WNW           44.0        NNW      ...             25.0
# 2         WSW           46.0          W      ...             30.0
# 3          NE           24.0         SE      ...             16.0
# 4           W           41.0        ENE      ...             33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
my_data.tail()
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am      ...       \
# 142188       NaN           E           31.0        ESE      ...
# 142189       NaN           E           31.0         SE      ...
# 142190       NaN         NNW           22.0         SE      ...
# 142191       NaN           N           37.0         SE      ...
# 142192       NaN          SE           28.0        SSE      ...
#
#        Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 142188        27.0       1024.7       1021.2       NaN       NaN      9.4
# ...

# %% [markdown]
# # THE .SHAPE ATTRIBUTE SHOWS THE TOTAL NUMBER ROWS AND THE TOTAL NUMBER OF COLUMNS OF THE DATAFRAME.

# %%
my_data.shape
# Out:
# (142193, 24)

# %% [markdown]
# # THE .INDEX ATTRIBUTE PROVIDES THE INDEX OF THE DATAFRAME.

# %%
my_data.index
# Out:
# RangeIndex(start=0, stop=142193, step=1)

# %% [markdown]
# # THE .COLUMNS ATTRIBUTE SHOWS THE NAMES OF EACH COLUMN IN THE DATAFRAME.

# %%
my_data.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# # THE .DTYPES ATTRIBUTE SHOWS THE DATA TYPES OF THE COLUMNS

# %%
my_data.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %% [markdown]
# # THE .UNIQUE() ATTRIBUTE SHOWS ALL THE UNIQUE VALUES IN A COLUMN.
# # AND IS APPLIED IN A SINGLE COLUMN AND NOT THE WHOLE DATAFRAME.

# %%
my_data['Location'].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %% [markdown]
# # THE .NUNIQUE() ATTRIBUTE SHOWS THE TOTAL NUMBER OF UNIQUE VALUES IN EACH COLUMN OF THE DATAFRAME. CAN BE APPLIED IN A SINGLE COLUMN AND ALSO THE WHOLE DATAFRAME.

# %%
my_data.nunique()
# Out:
# Date             3436
# Location           49
# MinTemp           389
# MaxTemp           505
# Rainfall          679
# Evaporation       356
# Sunshine          145
# WindGustDir        16
# WindGustSpeed      67
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       43
# WindSpeed3pm       44
# Humidity9am       101
# Humidity3pm       101
# Pressure9am       546
# Pressure3pm       549
# Cloud9am           10
# Cloud3pm           10
# Temp9am           440
# Temp3pm           500
# RainToday           2
# RISK_MM           681
# RainTomorrow        2
# dtype: int64

# %% [markdown]
# # THE .NUNIQUE() ATTRIBUTE APPLIED IN A SINGLE COLUMN "LOCATION".

# %%
my_data['Location'].nunique()
# Out:
# 49

# %% [markdown]
# # THE .COUNT() ATTRIBUTE SHOWS THE TOTAL NUMBER OF NON-NULL VALUES IN EACH COLUMN. IT CAN BE APPLIED ON A SINGLE COLUMN OR THE WHOLE DATAFRAME.

# %%
my_data['Location'].count()
# Out:
# 142193

# %% [markdown]
# # EXAMPLE OF THE .COUNT() ATTRIBUTE IN THE WHOLE DATAFRAME.

# %%
my_data.count()
# Out:
# Date             142193
# Location         142193
# MinTemp          141556
# MaxTemp          141871
# Rainfall         140787
# Evaporation       81350
# Sunshine          74377
# WindGustDir      132863
# WindGustSpeed    132923
# WindDir9am       132180
# WindDir3pm       138415
# WindSpeed9am     140845
# WindSpeed3pm     139563
# Humidity9am      140419
# Humidity3pm      138583
# Pressure9am      128179
# Pressure3pm      128212
# Cloud9am          88536
# Cloud3pm          85099
# Temp9am          141289
# Temp3pm          139467
# RainToday        140787
# RISK_MM          142193
# RainTomorrow     142193
# dtype: int64

# %% [markdown]
# # THE .VALUE_COUNTS() ATTRIBUTE SHOWS SHOWS ALL THE UNIQUE VALUES WITH THEIR COUNT IN A COLUMN. IT IS APPLIED ONLY TO A COLUMN.

# %%
my_data['Location'].value_counts()
# Out:
# Canberra            3418
# Sydney              3337
# Perth               3193
# Darwin              3192
# Hobart              3188
# Brisbane            3161
# Adelaide            3090
# Bendigo             3034
# Townsville          3033
# AliceSprings        3031
# MountGambier        3030
# Ballarat            3028
# Launceston          3028
# Albany              3016
# Albury              3011
# PerthAirport        3009
# MelbourneAirport    3009
# Mildura             3007
# SydneyAirport       3005
# Nuriootpa           3002
# Sale                3000
# Watsonia            2999
# Tuggeranong         2998
# Portland            2996
# Woomera             2990
# Cairns              2988
# Cobar               2988
# Wollongong          2983
# GoldCoast           2980
# WaggaWagga          2976
# NorfolkIsland       2964
# Penrith             2964
# Newcastle           2955
# SalmonGums          2955
# CoffsHarbour        2953
# Witchcliffe         2952
# Richmond            2951
# ...

# %% [markdown]
# # AN EXAMPLE OF THE .VALUE_COUNTS() ATTRIBUTE USED IN A COLUMN.

# %%
my_data['MinTemp'].value_counts()
# Out:
#  9.6     883
#  11.0    883
#  10.2    880
#  10.5    867
#  10.8    860
#  9.0     853
#  12.0    850
#  10.0    849
#  13.0    844
#  10.4    842
#  8.9     842
#  9.7     836
#  11.5    835
#  8.5     833
#  11.3    831
#  11.8    827
#  12.7    827
#  10.9    822
#  11.4    820
#  12.4    815
#  11.6    813
#  13.2    811
#  12.5    809
#  9.8     808
#  9.2     805
#  10.7    805
#  9.4     804
#  9.3     802
#  11.2    802
#  12.2    801
#         ...
# -6.6       4
#  29.3      4
#  29.2      4
# -5.7       4
# -6.2       3
#  31.4      3
# -6.8       3
# -8.0       2
# -7.6       2
# -8.2       2
#  29.6      2
#  30.7      2
# -7.5       2
# -6.9       2
#  29.5      1
# -7.2       1
#  31.2      1
#  31.9      1
#  31.8      1
# -7.1       1
#  29.9      1
#  30.3      1
# -8.5       1
#  29.8      1
#  33.9      1
#  31.0      1
#  30.2      1
# -7.3       1
# -7.8       1
#  30.5      1
# Name: MinTemp, Length: 389, dtype: int64

# %% [markdown]
# # THE .INFO() ATTRIBUTE SHOWS THE BASIC INFORMATION OF THE DATAFRAME.

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
# Date             142193 non-null object
# Location         142193 non-null object
# MinTemp          141556 non-null float64
# MaxTemp          141871 non-null float64
# Rainfall         140787 non-null float64
# Evaporation      81350 non-null float64
# Sunshine         74377 non-null float64
# WindGustDir      132863 non-null object
# WindGustSpeed    132923 non-null float64
# WindDir9am       132180 non-null object
# WindDir3pm       138415 non-null object
# WindSpeed9am     140845 non-null float64
# WindSpeed3pm     139563 non-null float64
# Humidity9am      140419 non-null float64
# Humidity3pm      138583 non-null float64
# Pressure9am      128179 non-null float64
# Pressure3pm      128212 non-null float64
# Cloud9am         88536 non-null float64
# Cloud3pm         85099 non-null float64
# Temp9am          141289 non-null float64
# ...

# %% [markdown]
# # Find all the Unique 'WindGustDir' values in the data

# %%
my_data.head(2)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0           W           44.0          W      ...             22.0
# 1         WNW           44.0        NNW      ...             25.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
#
#    RISK_MM  RainTomorrow
# 0      0.0            No
# 1      0.0            No
#
# [2 rows x 24 columns]

# %%
my_data.nunique()
# Out:
# Date             3436
# Location           49
# MinTemp           389
# MaxTemp           505
# Rainfall          679
# Evaporation       356
# Sunshine          145
# WindGustDir        16
# WindGustSpeed      67
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       43
# WindSpeed3pm       44
# Humidity9am       101
# Humidity3pm       101
# Pressure9am       546
# Pressure3pm       549
# Cloud9am           10
# Cloud3pm           10
# Temp9am           440
# Temp3pm           500
# RainToday           2
# RISK_MM           681
# RainTomorrow        2
# dtype: int64

# %%
my_data['WindGustDir'].nunique()
# Out:
# 16

# %%
my_data['WindGustDir'].unique() #Answer
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', 'ENE', 'SSE',
#        'S', 'NW', 'SE', 'ESE', nan, 'E', 'SSW'], dtype=object)
